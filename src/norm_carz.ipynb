# %% [markdown]
# # Normalizing data
#
# To be persited within RDMS, we will normalize given data
#
# - [Original data set](https://www.kaggle.com/datasets/CooperUnion/cardataset)

# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline     
sns.set_theme(color_codes=True)

# %%
# Importing data 
df = pd.read_csv("dta/cardata/data_san.csv")

df.head(23)
# Out:
#     Unnamed: 0  Make       Model  Year             Engine Fuel Type  \
# 0            0   BMW  1 Series M  2011  premium unleaded (required)
# 1            1   BMW    1 Series  2011  premium unleaded (required)
# 2            2   BMW    1 Series  2011  premium unleaded (required)
# 3            3   BMW    1 Series  2011  premium unleaded (required)
# 4            4   BMW    1 Series  2011  premium unleaded (required)
# 5            5   BMW    1 Series  2012  premium unleaded (required)
# 6            6   BMW    1 Series  2012  premium unleaded (required)
# 7            7   BMW    1 Series  2012  premium unleaded (required)
# 8            8   BMW    1 Series  2012  premium unleaded (required)
# 9            9   BMW    1 Series  2013  premium unleaded (required)
# 10          10   BMW    1 Series  2013  premium unleaded (required)
# 11          11   BMW    1 Series  2013  premium unleaded (required)
# 12          12   BMW    1 Series  2013  premium unleaded (required)
# 13          13   BMW    1 Series  2013  premium unleaded (required)
# 14          14   BMW    1 Series  2013  premium unleaded (required)
# 15          15   BMW    1 Series  2013  premium unleaded (required)
# 16          16   BMW    1 Series  2013  premium unleaded (required)
# 17          17  Audi         100  1992             regular unleaded
# 18          18  Audi         100  1992             regular unleaded
# 19          19  Audi         100  1992             regular unleaded
# 20          20  Audi         100  1992             regular unleaded
# 21          21  Audi         100  1992             regular unleaded
# 22          22  Audi         100  1993             regular unleaded
#
#     Engine HP  Engine Cylinders Transmission Type      Driven_Wheels  \
# 0       335.0               6.0            MANUAL   rear wheel drive
# 1       300.0               6.0            MANUAL   rear wheel drive
# 2       300.0               6.0            MANUAL   rear wheel drive
# 3       230.0               6.0            MANUAL   rear wheel drive
# 4       230.0               6.0            MANUAL   rear wheel drive
# 5       230.0               6.0            MANUAL   rear wheel drive
# 6       300.0               6.0            MANUAL   rear wheel drive
# 7       300.0               6.0            MANUAL   rear wheel drive
# 8       230.0               6.0            MANUAL   rear wheel drive
# 9       230.0               6.0            MANUAL   rear wheel drive
# 10      300.0               6.0            MANUAL   rear wheel drive
# 11      230.0               6.0            MANUAL   rear wheel drive
# 12      300.0               6.0            MANUAL   rear wheel drive
# 13      230.0               6.0            MANUAL   rear wheel drive
# 14      230.0               6.0            MANUAL   rear wheel drive
# 15      320.0               6.0            MANUAL   rear wheel drive
# 16      320.0               6.0            MANUAL   rear wheel drive
# 17      172.0               6.0            MANUAL  front wheel drive
# 18      172.0               6.0            MANUAL  front wheel drive
# 19      172.0               6.0         AUTOMATIC    all wheel drive
# 20      172.0               6.0            MANUAL  front wheel drive
# 21      172.0               6.0            MANUAL    all wheel drive
# 22      172.0               6.0            MANUAL  front wheel drive
#
#     Number of Doors                        Market Category Vehicle Size  \
# 0               2.0  Factory Tuner,Luxury,High-Performance      Compact
# 1               2.0                     Luxury,Performance      Compact
# 2               2.0                Luxury,High-Performance      Compact
# 3               2.0                     Luxury,Performance      Compact
# 4               2.0                                 Luxury      Compact
# 5               2.0                     Luxury,Performance      Compact
# 6               2.0                     Luxury,Performance      Compact
# 7               2.0                Luxury,High-Performance      Compact
# 8               2.0                                 Luxury      Compact
# 9               2.0                                 Luxury      Compact
# 10              2.0                Luxury,High-Performance      Compact
# 11              2.0                     Luxury,Performance      Compact
# 12              2.0                     Luxury,Performance      Compact
# 13              2.0                                 Luxury      Compact
# 14              2.0                     Luxury,Performance      Compact
# 15              2.0                Luxury,High-Performance      Compact
# 16              2.0                Luxury,High-Performance      Compact
# 17              4.0                                 Luxury      Midsize
# 18              4.0                                 Luxury      Midsize
# 19              4.0                                 Luxury      Midsize
# 20              4.0                                 Luxury      Midsize
# 21              4.0                                 Luxury      Midsize
# 22              4.0                                 Luxury      Midsize
#
#    Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 0          Coupe           26        19        3916  46135
# 1    Convertible           28        19        3916  40650
# 2          Coupe           28        20        3916  36350
# 3          Coupe           28        18        3916  29450
# 4    Convertible           28        18        3916  34500
# 5          Coupe           28        18        3916  31200
# 6    Convertible           26        17        3916  44100
# 7          Coupe           28        20        3916  39300
# 8    Convertible           28        18        3916  36900
# 9    Convertible           27        18        3916  37200
# 10         Coupe           28        20        3916  39600
# 11         Coupe           28        19        3916  31500
# 12   Convertible           28        19        3916  44400
# 13   Convertible           28        19        3916  37200
# 14         Coupe           28        19        3916  31500
# 15   Convertible           25        18        3916  48250
# 16         Coupe           28        20        3916  43550
# 17         Sedan           24        17        3105   2000
# 18         Sedan           24        17        3105   2000
# 19         Wagon           20        16        3105   2000
# 20         Sedan           24        17        3105   2000
# 21         Sedan           21        16        3105   2000
# 22         Sedan           24        17        3105   2000

# %%
colz_old = df.columns
npath = "dta/norm/"
colz_old
# Out:
# Index(['Unnamed: 0', 'Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
brndz = pd.DataFrame(df["Make"].unique())
#brndz['id'] = 123 + df.index
brndz.to_csv(npath + 'brndz.csv')
brndz.head()
# Out:
#                0
# 0            BMW
# 1           Audi
# 2           FIAT
# 3  Mercedes-Benz
# 4       Chrysler

# %%
tmp = pd.read_csv(npath + 'brndz.csv')
tmp['id'] = 123 + tmp['rownum']

tmp.to_csv(npath + 'brndz_idc.csv', index=False)

tmp
# Out:
# /var/folders/sq/2n461t452vd6tvf2zfbm2jq00000gn/T/ipykernel_7576/2634209106.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   tmp['id'] = 123 + tmp['rownum']
#     rownum          value   id
# 0        0            BMW  123
# 1        1           Audi  124
# 2        2           FIAT  125
# 3        3  Mercedes-Benz  126
# 4        4       Chrysler  127
# 5        5         Nissan  128
# 6        6          Volvo  129
# 7        7          Mazda  130
# 8        8     Mitsubishi  131
# 9        9        Ferrari  132
# 10      10     Alfa Romeo  133
# 11      11        McLaren  134
# 12      12        Maybach  135
# 13      13        Porsche  136
# 14      14         Toyota  137
# 15      15           Saab  138
# 16      16            GMC  139
# 17      17        Hyundai  140
# 18      18          Honda  141
# 19      19       Cadillac  142
# 20      20        Bentley  143
# 21      21           Ford  144
# 22      22     Oldsmobile  145
# 23      23      Chevrolet  146
# 24      24          Dodge  147
# 25      25    Lamborghini  148
# 26      26        Lincoln  149
# 27      27        Pontiac  150
# 28      28         Subaru  151
# 29      29     Volkswagen  152
# 30      30         Spyker  153
# 31      31            Kia  154
# 32      32          Acura  155
# 33      33       Plymouth  156
# 34      34    Rolls-Royce  157
# 35      35       Maserati  158
# 36      36          Lexus  159
# 37      37   Aston Martin  160
# 38      38     Land Rover  161
# 39      39          Lotus  162
# 40      40          Buick  163
# 41      41       Infiniti  164
# 42      42          Scion  165
# 43      43        Genesis  166
# 44      44         Suzuki  167
# 45      45         HUMMER  168
# 46      46        Bugatti  169

# %%
df.head()
# Out:
#    Unnamed: 0 Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0           0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1           1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2           2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3           3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4           4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
norm_colz = ["Engine Fuel Type", "Transmission Type", "Driven_Wheels", "Market Category", "Vehicle Size", "Vehicle Style"]
sfx = '.csv'

for x in norm_colz:
    fn = npath+ x.replace(" ", "") + sfx
    print(x, fn)
    tmp = pd.DataFrame(df[x].unique())
    tmp.to_csv(fn)
# Out:
# Engine Fuel Type dta/norm/EngineFuelType.csv
# Transmission Type dta/norm/TransmissionType.csv
# Driven_Wheels dta/norm/Driven_Wheels.csv
# Market Category dta/norm/MarketCategory.csv
# Vehicle Size dta/norm/VehicleSize.csv
# Vehicle Style dta/norm/VehicleStyle.csv
