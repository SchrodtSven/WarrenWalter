# %% [markdown]
# # Normalizing data
#
# To be persited within RDMS, we will normalize given data
#
# - [Original data set](https://www.kaggle.com/datasets/CooperUnion/cardataset)

# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline     
sns.set_theme(color_codes=True)

# %%
# Importing data 
df = pd.read_csv("dta/cardata/data_san.csv")

df.head(23)
# Out:
#     id  Make     Model  Year             Engine_Fuel_Type  Engine_HP  \
# 0    1   BMW  1 Series  2011  premium unleaded (required)      300.0
# 1    2   BMW  1 Series  2011  premium unleaded (required)      300.0
# 2    3   BMW  1 Series  2011  premium unleaded (required)      230.0
# 3    4   BMW  1 Series  2011  premium unleaded (required)      230.0
# 4    5   BMW  1 Series  2012  premium unleaded (required)      230.0
# 5    6   BMW  1 Series  2012  premium unleaded (required)      300.0
# 6    7   BMW  1 Series  2012  premium unleaded (required)      300.0
# 7    8   BMW  1 Series  2012  premium unleaded (required)      230.0
# 8    9   BMW  1 Series  2013  premium unleaded (required)      230.0
# 9   10   BMW  1 Series  2013  premium unleaded (required)      300.0
# 10  11   BMW  1 Series  2013  premium unleaded (required)      230.0
# 11  12   BMW  1 Series  2013  premium unleaded (required)      300.0
# 12  13   BMW  1 Series  2013  premium unleaded (required)      230.0
# ...

# %%
colz_old = df.columns
npath = "dta/norm/"
colz_old
# Out:
# Index(['Unnamed: 0', 'Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
brndz = pd.DataFrame(df["Make"].unique())
#brndz['id'] = 123 + df.index
brndz.to_csv(npath + 'brndz.csv')
brndz.head()
# Out:
#                0
# 0            BMW
# 1           Audi
# 2           FIAT
# 3  Mercedes-Benz
# 4       Chrysler

# %%
tmp = pd.read_csv(npath + 'brndz.csv')
tmp['id'] = 123 + tmp['rownum']

tmp.to_csv(npath + 'brndz_idc.csv', index=False)

tmp
# Out:
# /var/folders/sq/2n461t452vd6tvf2zfbm2jq00000gn/T/ipykernel_7576/2634209106.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   tmp['id'] = 123 + tmp['rownum']
#     rownum          value   id
# ...

# %%
df.head()
# Out:
#    Unnamed: 0 Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0           0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1           1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2           2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3           3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4           4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
# ...

# %%
from pyapml.normalize import Normalize

# %%
norm_colz = [
    "Engine Fuel Type",
    "Transmission Type",
    "Driven_Wheels",
    "Market Category",
    "Vehicle Size",
    "Vehicle Style",
    "Brndz",
]
sfx = ".csv"
npath = "dta/norm/"
for x in norm_colz:
    fn = npath + x.replace(" ", "") + sfx
    nw_nm = npath + Normalize.sanitize_name(x) + sfx
    print("mv", fn, nw_nm)
    # tmp = pd.DataFrame(df[x].unique())
    # tmp.to_csv(fn)
# Out:
# mv dta/norm/EngineFuelType.csv dta/norm/Engine_Fuel_Type.csv
# mv dta/norm/TransmissionType.csv dta/norm/Transmission_Type.csv
# mv dta/norm/Driven_Wheels.csv dta/norm/Driven_Wheels.csv
# mv dta/norm/MarketCategory.csv dta/norm/Market_Category.csv
# mv dta/norm/VehicleSize.csv dta/norm/Vehicle_Size.csv
# mv dta/norm/VehicleStyle.csv dta/norm/Vehicle_Style.csv
# mv dta/norm/Brndz.csv dta/norm/Brndz.csv

# %%
df.head()
# Out:
#    id Make     Model  Year             Engine_Fuel_Type  Engine_HP  \
# 0   1  BMW  1 Series  2011  premium unleaded (required)      300.0
# 1   2  BMW  1 Series  2011  premium unleaded (required)      300.0
# 2   3  BMW  1 Series  2011  premium unleaded (required)      230.0
# 3   4  BMW  1 Series  2011  premium unleaded (required)      230.0
# 4   5  BMW  1 Series  2012  premium unleaded (required)      230.0
#
#    Engine_Cylinders Transmission_Type     Driven_Wheels  Number_of_Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#            Market_Category Vehicle_Size Vehicle_Style  highway_MPG  city_mpg  \
# ...

# %%
m = df["Market_Category"].unique()


mc = []

for x in m:
    tmp = x.split(",")
    for y in tmp:
        mc.append(y)



uniq = set(mc)

print("\n".join(uniq))
# Out:
# Hybrid
# Exotic
# High-Performance
# Factory Tuner
# Performance
# Hatchback
# Diesel
# Crossover
# Flex Fuel
# Luxury

# %%
mark = pd.read_csv("dta/norm/mar_k_v.csv")
mark["value"] = pow(2,mark["id"])
mark.to_csv("dta/norm/mkv.csv", index =False)
# Out:
# /var/folders/sq/2n461t452vd6tvf2zfbm2jq00000gn/T/ipykernel_11499/1932675076.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   mark["value"] = pow(2,mark["id"])
