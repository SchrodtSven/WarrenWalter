# %%
# Importing 3rd party packages
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

# %%
# own stuff
import pyapml.dectree as dt

df = dt.importdata()
dt
# Out:
# Dataset Length:  625
# Dataset Shape:  (625, 5)
# Dataset:     0  1  2  3  4
# 0  B  1  1  1  1
# 1  R  1  1  1  2
# 2  R  1  1  1  3
# 3  R  1  1  1  4
# 4  R  1  1  1  5
# <module 'pyapml.dectree' from '/Users/svenschrodt/projx/WarrenWalter/pyapml/dectree.py'>

# %%
data = dt.importdata()
#data.head()

X, Y, X_train, X_test, y_train, y_test = dt.splitdataset(data)

clf_gini = dt.train_using_gini(X_train, X_test, y_train)
clf_entropy = dt.train_using_entropy(X_train, X_test, y_train)

# Visualizing the Decision Trees
dt.plot_decision_tree(clf_gini, ['X1', 'X2', 'X3', 'X4'], ['L', 'B', 'R'])
dt.plot_decision_tree(clf_entropy, ['X1', 'X2', 'X3', 'X4'], ['L', 'B', 'R'])
# Out:
# Dataset Length:  625
# Dataset Shape:  (625, 5)
# Dataset:     0  1  2  3  4
# 0  B  1  1  1  1
# 1  R  1  1  1  2
# 2  R  1  1  1  3
# 3  R  1  1  1  4
# 4  R  1  1  1  5
