# %%
# Importing 3rd party packages
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

# %%
# own stuff
import pyapml.dectree as dt

df = dt.importdata()
df
# Out:
# Dataset Length:  625
# Dataset Shape:  (625, 5)
# Dataset:     0  1  2  3  4
# 0  B  1  1  1  1
# 1  R  1  1  1  2
# 2  R  1  1  1  3
# 3  R  1  1  1  4
# 4  R  1  1  1  5
#      0  1  2  3  4
# 0    B  1  1  1  1
# 1    R  1  1  1  2
# 2    R  1  1  1  3
# 3    R  1  1  1  4
# 4    R  1  1  1  5
# ..  .. .. .. .. ..
# 620  L  5  5  5  1
# 621  L  5  5  5  2
# 622  L  5  5  5  3
# 623  L  5  5  5  4
# 624  B  5  5  5  5
#
# [625 rows x 5 columns]

# %%
data = dt.importdata()
#data.head()

X, Y, X_train, X_test, y_train, y_test = dt.splitdataset(data)

# clf_gini = dt.train_using_gini(X_train, X_test, y_train)
# clf_entropy = dt.train_using_entropy(X_train, X_test, y_train)

# # Visualizing the Decision Trees
# dt.plot_decision_tree(clf_gini, ['X1', 'X2', 'X3', 'X4'], ['L', 'B', 'R'])
# dt.plot_decision_tree(clf_entropy, ['X1', 'X2', 'X3', 'X4'], ['L', 'B', 'R'])
# Out:
# Dataset Length:  625
# Dataset Shape:  (625, 5)
# Dataset:     0  1  2  3  4
# 0  B  1  1  1  1
# 1  R  1  1  1  2
# 2  R  1  1  1  3
# 3  R  1  1  1  4
# 4  R  1  1  1  5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 3
#       1 data = dt.importdata()
#       2 data.head()
# ----> 3 X, Y, X_train, X_test, y_train, y_test = dt.splitdataset(data)
#       5 # clf_gini = dt.train_using_gini(X_train, X_test, y_train)
#       6 # clf_entropy = dt.train_using_entropy(X_train, X_test, y_train)
#       7
#       8 # # Visualizing the Decision Trees
#       9 # dt.plot_decision_tree(clf_gini, ['X1', 'X2', 'X3', 'X4'], ['L', 'B', 'R'])
#      10 # dt.plot_decision_tree(clf_entropy, ['X1', 'X2', 'X3', 'X4'], ['L', 'B', 'R'])
#
# AttributeError: module 'pyapml.dectree' has no attribute 'splitdataset'
